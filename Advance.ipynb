# %% [markdown]
# # 1. Line Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

var = [1, 2, 3, 4, 5, 6, 7]
var_1 = [2, 3, 4, 1, 5, 6, 7]

x_1 = pd.DataFrame({"var": var, "var_1": var_1})
print(x_1)
sns.lineplot(y = 'var_1', x="var", data=x_1)
plt.show()
# Out:
#    var  var_1
# 0    1      2
# 1    2      3
# 2    3      4
# 3    4      1
# 4    5      5
# 5    6      6
# 6    7      7

# %%
sns.lineplot(x=var, y=var_1)
plt.show()

# %%
y_1 = sns.load_dataset("penguins").head(25)
y_1
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.lineplot(x = 'bill_length_mm', y="flipper_length_mm", data=y_1, hue='sex', dashes=False, style='sex', palette='Accent', markers=['o', '<'], legend=False) # palette use for custom color # dases remove doted and make it line

plt.grid()
plt.title('laksh')
plt.show()

# %% [markdown]
# # 2. Bar Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

vars = sns.load_dataset('penguins')
vars
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
import seaborn as sns
order_1 = ['Adelie', 'Gentoo', 'Chinstrap']
sns.barplot(x=vars.species, y=vars.bill_depth_mm, hue=vars.sex, hue_order=['Female', 'Male'], order=order_1, palette='dark:r', saturation=0.5, err_kws={'color': 'y', 'linewidth': 3}, capsize=0.3, dodge=True, alpha=0.9)
# 'ci' is blacks line on every top of bar value must be in [0 to 100]# 'n_boot' is do something up or down as theird value, # palette='dark:r' ==== color='r' <-- both are same, use any. and here we can use color but use "palette" # "saturation" give it change little bit color # "dodge" method override each other one seame bar upper side another color lower side another color # "alpha" use for light our chart color

plt.show()

# %% [markdown]
# ### horizontal

# %%
# when we are create bar plot horizontaly then both of them value must be numeric(number)
sns.barplot(x=vars.bill_length_mm, y=vars.bill_depth_mm, orient='h') # ci is black line on every bar # n boot is do something up or down as theird value
plt.show()

# %% [markdown]
# # 2. Histogram Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

var = sns.load_dataset('penguins')
var
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.displot(var.bill_length_mm, bins = [30, 35, 40, 45, 50, 55, 60], kde = True, color='g') # Using 'kde' we can show also one below shown one more chart to more clearity of data

plt.show()

# %% [markdown]
# # 3. Scatter Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
scatData = var.head(20)
scatData
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 3   Adelie  Torgersen             NaN            NaN                NaN
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 8   Adelie  Torgersen            34.1           18.1              193.0
# 9   Adelie  Torgersen            42.0           20.2              190.0
# 10  Adelie  Torgersen            37.8           17.1              186.0
# 11  Adelie  Torgersen            37.8           17.3              180.0
# ...

# %%
sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', data = scatData, hue='sex', style='sex', size='sex', sizes=[30, 40], palette='gist_ncar', alpha=0.5, markers=['o', '*']) # sizes override size # palette use gor give color
plt.show()

# %% [markdown]
# # 4. Heatmap

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

datas = var
datas
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
heatMap = np.linspace(1, 10, 20).reshape(4, 5)
heatMap
# Out:
# array([[ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684],
#        [ 3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789],
#        [ 5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895],
#        [ 8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]])

# %%
sns.heatmap(heatMap)
# Out:
# <Axes: >

# %%
data = sns.load_dataset("anagrams")
x = data.drop(columns='attnr', index=1).head(10)
x
# Out:
#     subidr  num1  num2  num3
# 0        1     2   4.0     7
# 2        3     3   5.0     6
# 3        4     5   7.0     5
# 4        5     4   5.0     8
# 5        6     5   5.0     6
# 6        7     5   4.5     6
# 7        8     5   7.0     8
# 8        9     2   3.0     7
# 9       10     6   5.0     6
# 10      11     6   5.0     6

# %%
y = {'fontsize': 15, 'color': 'b'}
v = sns.heatmap(x, vmin=0, vmax=12, cmap='flare', annot=True, annot_kws=y, linewidths=1, linecolor='y', cbar=True, xticklabels=False, yticklabels=True) 
# vmin & vmax set color size # cmap for give custom color, # annot give value in square # cbar false remove color bar
v.set(xlabel='python', ylabel='laksh')
plt.show()

# %% [markdown]
# # 5. Count Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

var = sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Count plow show counting
sns.countplot(x = 'sex', data=var, hue='smoker', palette='jet_r')
# for horizontal remove comment below
# sns.countplot(y = 'sex', data=var, hue='smoker')
plt.show()

# %%
# bar plot show mean(average)
sns.barplot(x='sex', y='size', data=var)
plt.show()

# %% [markdown]
# # 6. Violin Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

var = sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(x='day', y='total_bill', data=var, hue='time')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day', y='total_bill', data=var, linewidth=1, linecolor='g', palette='jet_r', hue='sex', split=True,  order=['Fri', 'Thur', 'Sun', 'Sat'])
# Do it horizontaly remove below comment
# sns.violinplot(y='day', x='total_bill', data=var)
plt.show()

# %%
# for single violin
sns.violinplot(x=var['total_bill'])
# for vertical remove below comment
# sns.violinplot(y=var['total_bill'])
plt.show()

# %% [markdown]
# # 7. Pair Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

var = sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(var,hue='sex', x_vars=['total_bill', 'tip'])
plt.show()

# %% [markdown]
# # 8. Strip Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

var = sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.stripplot(x="day", y="total_bill", data=var, hue="sex",
              palette='rocket_r', linewidth=1, edgecolor="r",
              size=5, alpha=0.2)
plt.show()

# %% [markdown]
# # 9. Box Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

var = sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style="whitegrid")
sns.boxplot(x='day', y = 'total_bill', data = var, hue='smoker', showmeans= True, meanprops={'marker': '*', 'markeredgecolor':'r'}, linewidth=1, linecolor='g')

plt.show()

# %% [markdown]
# # 10. Factor Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

var = sns.load_dataset('tips').head(20)
var
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
# in kind option we can write "strip, swarm, box, violin, boxen, point, bar, count"
sns.catplot(x = 'size', y='tip', data=var, hue='sex', kind='point')
plt.show()

# %% [markdown]
# # 11. Styling Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns

var = sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style("darkgrid") # we can also write "white, whitegrid, dark, darkgrid, ticks <-- bydefault"
sns.barplot(x='day', y='total_bill', data=var)
plt.grid() # after set gridin style show in vertical way
plt.show()

# %%
sns.set_style("whitegrid") 
sns.barplot(x='day', y='total_bill', data=var)

sns.despine() # for remove top and right line remove
plt.show()

# %% [markdown]
# # 12. Multiple Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

var = sns.load_dataset('tips')
var
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fg = sns.FacetGrid(var, col='day', hue='sex')

fg.map(plt.scatter, 'total_bill', 'tip').add_legend()

plt.show()
